# %% [markdown]
# <a href="https://colab.research.google.com/github/jelly-decoder28/poppy-june/blob/intro_to_AI-programming-course!/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files #Import the matplotlib library to store the image and proccess for use
uploaded = files.upload()
# Out:
#      <input type="file" id="files-534745a5-a09c-48fc-b5f4-c5d559796ae4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-534745a5-a09c-48fc-b5f4-c5d559796ae4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Fav Genshin Characters  - Sheet1 (1) (3).csv')
print(df.head(5))
# Out:
#     Unnamed: 0             Unnamed: 1                  Unnamed: 2  \
# 0         Name  Upgrade material Used            Best Weapon Used
# 1       Chasca         Silken Feather            Thundering Pulse
# 2         Klee                Freedom               Skyward Atlas
# 3       Raiden          Amakumo Fruit  Staff of the Scarlet Sands
# 4  Wriothesley  Primordial Greenbloom              Flowing Purity
#
#                  Unnamed: 3 Unnamed: 4
# 0         Artifact obtained    ATK (%)
# 1  Shimenawa's Reminiscence         65
# 2               Lava Walker         80
# 3           Noblesse Oblige         45
# 4       Marechaussee Hunter         70

# %%
print(df.columns)
print(df.iloc[1:4])
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')
#   Unnamed: 0      Unnamed: 1                  Unnamed: 2  \
# 1     Chasca  Silken Feather            Thundering Pulse
# 2       Klee         Freedom               Skyward Atlas
# 3     Raiden   Amakumo Fruit  Staff of the Scarlet Sands
#
#                  Unnamed: 3 Unnamed: 4
# 1  Shimenawa's Reminiscence         65
# 2               Lava Walker         80
# 3           Noblesse Oblige         45
# Freedom

# %%
print(df.iloc[2,1])
# Out:
# Freedom

# %%
print(df.iloc[::3])
# Out:
#   Unnamed: 0             Unnamed: 1                  Unnamed: 2  \
# 0       Name  Upgrade material Used            Best Weapon Used
# 3     Raiden          Amakumo Fruit  Staff of the Scarlet Sands
# 6      Kaeya                 Ballad    Light of Foliar Incision
# 9       Xiao                Qingxin               Staff of Homa
#
#                   Unnamed: 3 Unnamed: 4
# 0          Artifact obtained    ATK (%)
# 3            Noblesse Oblige         45
# 6                 Instructor         20
# 9  Desert Pavilion Chronicle         90

# %%
print(df.iloc[::3, ::3])
# Out:
#   Unnamed: 0                 Unnamed: 3
# 0       Name          Artifact obtained
# 3     Raiden            Noblesse Oblige
# 6      Kaeya                 Instructor
# 9       Xiao  Desert Pavilion Chronicle

# %%
df['Total'] = df['Unnamed: 1'] + df['Unnamed: 2']
df.head(5)
# Out:
#     Unnamed: 0             Unnamed: 1                  Unnamed: 2  \
# 0         Name  Upgrade material Used            Best Weapon Used
# 1       Chasca         Silken Feather            Thundering Pulse
# 2         Klee                Freedom               Skyward Atlas
# 3       Raiden          Amakumo Fruit  Staff of the Scarlet Sands
# 4  Wriothesley  Primordial Greenbloom              Flowing Purity
#
#                  Unnamed: 3 Unnamed: 4  \
# 0         Artifact obtained    ATK (%)
# 1  Shimenawa's Reminiscence         65
# 2               Lava Walker         80
# 3           Noblesse Oblige         45
# 4       Marechaussee Hunter         70
#
#                                      Total
# 0    Upgrade material UsedBest Weapon Used
# 1           Silken FeatherThundering Pulse
# 2                     FreedomSkyward Atlas
# 3  Amakumo FruitStaff of the Scarlet Sands
# 4      Primordial GreenbloomFlowing Purity
